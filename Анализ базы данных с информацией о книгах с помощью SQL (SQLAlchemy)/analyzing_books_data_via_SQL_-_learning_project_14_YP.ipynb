# %% [markdown]
# # Анализ данных с помощью SQL

# %% [markdown]
# # Содержание
#
# [Доступ к базе данных](#Доступ-к-базе-данных)
#
# [Исходные данные](#Исходные-данные)
# 1. [Количество книг, вышедших после 1 января 2000 года](#1.-Количество-книг,-вышедших-после-1-января-2000-года)
# 2. [Определение количества обзоров и средней оценки для каждой книги](#2.-Определение-количества-обзоров-и-средней-оценки-для-каждой-книги)
# 3. [Определение издательства, выпустившего наибольшее число книг толще 50 страниц](#3.-Определение-издательства,-выпустившего-наибольшее-число-книг-толще-50-страниц)
# 4. [Определение автора с самой высокой средней оценкой книг](#4.-Определение-автора-с-самой-высокой-средней-оценкой-книг-(учитываются-только-книги-с-50-и-более-оценками))
# 5. [Определение среднего количества обзоров от пользователей](#5.-Определение-среднего-количества-обзоров-от-пользователей,-которые-поставили-больше-50-оценок)

# %% [markdown]
# # Доступ к базе данных

# %%
# импорт библиотек

import pandas as pd
from sqlalchemy import create_engine

# кофигурации для подключения находятся в отдельном файле

from configuration import user
from configuration import password
from configuration import host
from configuration import port
from configuration import database

# установка параметров
db_config = {'user': user, # имя пользователя
 'pwd': password, # пароль
 'host': host,
 'port': port, # порт подключения
 'db': database} # название базы данных

connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(db_config['user'],
 db_config['pwd'],
 db_config['host'],
 db_config['port'],
 db_config['db'])

# сохранение коннектора
engine = create_engine(connection_string, connect_args={'sslmode':'require'})

# %% [markdown]
# Можно написать функцию SQL-запроса:

# %%
# SQL-запрос через Pandas:
# pd.io.sql.read_sql(query, con = engine) 

def func_query(sql_query):
    return pd.io.sql.read_sql(sql_query, con = engine)

# %% [markdown]
# # Исходные данные

# %%
# данные о книгах

func_query('SELECT * FROM books')
# Out:
#      book_id  author_id                                              title  \
# 0          1        546                                       'Salem's Lot
# 1          2        465                 1 000 Places to See Before You Die
# 2          3        407  13 Little Blue Envelopes (Little Blue Envelope...
# 3          4         82  1491: New Revelations of the Americas Before C...
# 4          5        125                                               1776
# ..       ...        ...                                                ...
# 995      996        571           Wyrd Sisters (Discworld  #6; Witches #2)
# 996      997        454                        Xenocide (Ender's Saga  #3)
# 997      998        201                                    Year of Wonders
# 998      999         94                        You Suck (A Love Story  #2)
# 999     1000        509  Zen and the Art of Motorcycle Maintenance: An ...
#
#      num_pages publication_date  publisher_id
# 0          594       2005-11-01            93
# 1          992       2003-05-22           336
# 2          322       2010-12-21           135
# 3          541       2006-10-10           309
# 4          386       2006-07-04           268
# ..         ...              ...           ...
# 995        265       2001-02-06           147
# 996        592       1996-07-15           297
# 997        358       2002-04-30           212
# 998        328       2007-01-16           331
# 999        540       2006-04-25           143
#
# [1000 rows x 6 columns]

# %%
# данные об авторах
func_query('SELECT * FROM authors')
# Out:
#      author_id                                author
# 0            1                            A.S. Byatt
# 1            2        Aesop/Laura Harris/Laura Gibbs
# 2            3                       Agatha Christie
# 3            4                         Alan Brennert
# 4            5              Alan Moore/David   Lloyd
# ..         ...                                   ...
# 631        632         William Strunk Jr./E.B. White
# 632        633                           Zadie Smith
# 633        634                 Zilpha Keatley Snyder
# 634        635                    Zora Neale Hurston
# 635        636  Åsne Seierstad/Ingrid Christopherson
#
# [636 rows x 2 columns]

# %%
# данные об издательствах
func_query('SELECT * FROM publishers')
# Out:
#      publisher_id                          publisher
# 0               1                                Ace
# 1               2                           Ace Book
# 2               3                          Ace Books
# 3               4                      Ace Hardcover
# 4               5  Addison Wesley Publishing Company
# ..            ...                                ...
# 335           336         Workman Publishing Company
# 336           337                         Wyatt Book
# 337           338              Yale University Press
# 338           339                           Yearling
# 339           340                     Yearling Books
#
# [340 rows x 2 columns]

# %%
# данные о пользовательских оценках книг
func_query('SELECT * FROM ratings')
# Out:
#       rating_id  book_id        username  rating
# 0             1        1      ryanfranco       4
# 1             2        1   grantpatricia       2
# 2             3        1    brandtandrea       5
# 3             4        2        lorichen       3
# 4             5        2     mariokeller       2
# ...         ...      ...             ...     ...
# 6451       6452     1000  carolrodriguez       4
# 6452       6453     1000         wendy18       4
# 6453       6454     1000      jarvispaul       5
# 6454       6455     1000           zross       2
# 6455       6456     1000         fharris       5
#
# [6456 rows x 4 columns]

# %%
# данные о пользовательских обзорах на книги
func_query('SELECT * FROM reviews')
# Out:
#       review_id  book_id        username  \
# 0             1        1    brandtandrea
# 1             2        1      ryanfranco
# 2             3        2        lorichen
# 3             4        3   johnsonamanda
# 4             5        3     scotttamara
# ...         ...      ...             ...
# 2788       2789      999      martinadam
# 2789       2790     1000         wknight
# 2790       2791     1000  carolrodriguez
# 2791       2792     1000         wendy18
# 2792       2793     1000      jarvispaul
#
#                                                    text
# 0     Mention society tell send professor analysis. ...
# 1     Foot glass pretty audience hit themselves. Amo...
# 2     Listen treat keep worry. Miss husband tax but ...
# 3     Finally month interesting blue could nature cu...
# 4     Nation purpose heavy give wait song will. List...
# ...                                                 ...
# 2788  Later hospital turn easy community. Fact same ...
# 2789   Change lose answer close pressure. Spend so now.
# 2790  Authority go who television entire hair guy po...
# 2791  Or western offer wonder ask. More hear phone f...
# 2792  Republican staff bit eat material measure plan...
#
# [2793 rows x 4 columns]

# %% [markdown]
# # 1. Количество книг, вышедших после 1 января 2000 года

# %%
func_query("SELECT COUNT (*) FROM books WHERE publication_date > '2000-01-01' ;")
# Out:
#    count
# 0    819

# %% [markdown]
# # 2. Определение количества обзоров и средней оценки для каждой книги

# %% [markdown]
# Определение средней оценки по id книги:

# %%
"""
SELECT AVG(rating) AS avg_rating,
book_id
FROM ratings
GROUP BY book_id
ORDER BY avg_rating
"""
func_query('SELECT book_id, AVG(rating) AS avg_rating FROM ratings GROUP BY book_id ORDER BY avg_rating')
# Out:
#      book_id  avg_rating
# 0        303        1.50
# 1        202        2.00
# 2        371        2.00
# 3        316        2.00
# 4        915        2.25
# ..       ...         ...
# 995      182        5.00
# 996      599        5.00
# 997       62        5.00
# 998      913        5.00
# 999      441        5.00
#
# [1000 rows x 2 columns]

# %% [markdown]
# Определение числа обзоров по id книги:

# %%
func_query(
    '''
SELECT COUNT(review_id) AS reviews_count, book_id
FROM reviews
GROUP BY book_id
ORDER BY reviews_count
'''
)
# Out:
#      reviews_count  book_id
# 0                1      129
# 1                1      187
# 2                1      156
# 3                1      760
# 4                1      248
# ..             ...      ...
# 989              6      656
# 990              6      733
# 991              6      734
# 992              6      207
# 993              7      948
#
# [994 rows x 2 columns]

# %% [markdown]
# Определение средней оценки по названию книги:

# %%
func_query(
    '''
SELECT AVG(rating) as avg_rating, title

    FROM (SELECT *
        FROM ratings

        INNER JOIN books ON ratings.book_id = books.book_id) AS SQBT
    GROUP BY title
    ORDER BY avg_rating
'''
)
# Out:
#      avg_rating                                              title
# 0          1.50                               Harvesting the Heart
# 1          2.00                                              Junky
# 2          2.00                                      Drowning Ruth
# 3          2.00                  His Excellency: George Washington
# 4          2.25  The World Is Flat: A Brief History of the Twen...
# ..          ...                                                ...
# 994        5.00            School's Out—Forever (Maximum Ride  #2)
# 995        5.00                    Act of Treason (Mitch Rapp  #9)
# 996        5.00  Wherever You Go  There You Are: Mindfulness Me...
# 997        5.00                                        Marvel 1602
# 998        5.00                                              Women
#
# [999 rows x 2 columns]

# %% [markdown]
# Определение числа обзоров по названию книги:

# %%
func_query(
    '''
SELECT COUNT(review_id) AS review_count, title

    FROM (SELECT *
        FROM reviews

        INNER JOIN books ON reviews.book_id = books.book_id) AS SQBT
    GROUP BY title
    ORDER BY review_count
'''
)
# Out:
#      review_count                                              title
# 0               1  Everyday Italian: 125 Simple and Delicious Rec...
# 1               1                  Winter Prey (Lucas Davenport  #5)
# 2               1                  Naked Empire (Sword of Truth  #8)
# 3               1                                          Babyville
# 4               1                              Ten Apples Up On Top!
# ..            ...                                                ...
# 988             6  Harry Potter and the Prisoner of Azkaban (Harr...
# 989             6                                           The Road
# 990             6                          Outlander (Outlander  #1)
# 991             7                            Twilight (Twilight  #1)
# 992             8                                Memoirs of a Geisha
#
# [993 rows x 2 columns]

# %% [markdown]
# Можно заметить разницу в количестве обзоров. Это связано с разным количеством id книг:

# %%
# данные о книгах
func_query(
    """SELECT COUNT(DISTINCT(book_id)) AS books_id_total
    FROM books"""
)
# Out:
#    books_id_total
# 0            1000

# %%
# данные об обзорах
func_query(
    """SELECT COUNT(DISTINCT(book_id)) AS books_id_total
    FROM reviews"""
)
# Out:
#    books_id_total
# 0             994

# %%
# данные о пользовательсктх рейтингах
func_query(
    """SELECT COUNT(DISTINCT(book_id)) AS books_id_total
    FROM ratings"""
)
# Out:
#    books_id_total
# 0            1000

# %% [markdown]
# Также для одной книги (с одним названием) может быть несколько id:

# %%
func_query(
    """SELECT book_id, title, publisher_id
    FROM books
    WHERE title = 'Memoirs of a Geisha'"""
)
# Out:
#    book_id                title  publisher_id
# 0      426  Memoirs of a Geisha           241
# 1      427  Memoirs of a Geisha           311

# %% [markdown]
# Это обусловлено разными издательствами, которые выпускали книгу, и годом выпуска.

# %% [markdown]
# Значения средней оценки и числа обзоров книг можно представить в виде объединённой таблицы:

# %%
func_query(
    '''
SELECT SQBT3.title, avg_rating, review_count
FROM
    (SELECT AVG(rating) as avg_rating, title
    FROM
        (SELECT *
        FROM ratings

        INNER JOIN books ON ratings.book_id = books.book_id) AS SQBT
        GROUP BY title) AS SQBT3
INNER JOIN (
            SELECT COUNT(review_id) AS review_count, title

            FROM
                (SELECT *
                FROM reviews

                INNER JOIN books ON reviews.book_id = books.book_id) AS SQBT2
                GROUP BY title) AS SQBT4 ON SQBT3.title = SQBT4.title
ORDER BY avg_rating DESC
'''
)
# Out:
#                                                  title  avg_rating  \
# 0              School's Out—Forever (Maximum Ride  #2)        5.00
# 1    The War of Art: Break Through the Blocks & Win...        5.00
# 2            A Woman of Substance (Emma Harte Saga #1)        5.00
# 3                    Misty of Chincoteague (Misty  #1)        5.00
# 4    In the Hand of the Goddess (Song of the Liones...        5.00
# ..                                                 ...         ...
# 988  The World Is Flat: A Brief History of the Twen...        2.25
# 989                                              Junky        2.00
# 990                  His Excellency: George Washington        2.00
# 991                                      Drowning Ruth        2.00
# 992                               Harvesting the Heart        1.50
#
#      review_count
# 0               3
# 1               2
# 2               2
# 3               2
# 4               2
# ..            ...
# 988             3
# 989             2
# 990             2
# 991             3
# 992             2
#
# [993 rows x 3 columns]

# %% [markdown]
# # 3. Определение издательства, выпустившего наибольшее число книг толще 50 страниц

# %% [markdown]
# Определение id первых 3 издательств по наибольшему числу книг:

# %%
func_query(
    """
    SELECT publisher_id, COUNT(book_id) AS books_count
    FROM books
    WHERE num_pages > 50
    GROUP BY publisher_id
    ORDER BY books_count DESC
    LIMIT 3
    """
)
# Out:
#    publisher_id  books_count
# 0           212           42
# 1           309           31
# 2           116           25

# %% [markdown]
# Определение названий первых 3 издательств по наибольшему числу книг:

# %%
func_query(
    """
    SELECT publisher, COUNT(book_id) AS books_count
    FROM
        (SELECT *
        FROM publishers
        INNER JOIN books ON publishers.publisher_id = books.publisher_id) AS SQBT
        GROUP BY publisher
        ORDER BY books_count DESC
        LIMIT 3
    """
)
# Out:
#                   publisher  books_count
# 0             Penguin Books           42
# 1                   Vintage           31
# 2  Grand Central Publishing           25

# %% [markdown]
# Больше всего книг выпустило издательство Penguin Books.

# %% [markdown]
# # 4. Определение автора с самой высокой средней оценкой книг (учитываются только книги с 50 и более оценками)

# %% [markdown]
# Определение id книг с самой высокой оценкой (при наличии 50 и более оценок):

# %%
func_query(
    """
    SELECT book_id, AVG(rating) AS avg_rating, COUNT(rating) AS ratings_count
    FROM
    ratings
    GROUP BY book_id
    HAVING COUNT(rating) > 50 OR COUNT(rating) = 50
    ORDER BY avg_rating DESC
    """
)
# Out:
#     book_id  avg_rating  ratings_count
# 0       302    4.414634             82
# 1       722    4.391892             74
# 2       299    4.287500             80
# 3       656    4.264151             53
# 4       300    4.246575             73
# 5       399    4.192308             52
# 6       301    4.186667             75
# 7       750    4.125000             88
# 8       779    4.080645             62
# 9       405    3.901408             71
# 10      696    3.830508             59
# 11      673    3.825581             86
# 12      627    3.789474             57
# 13      545    3.787879             66
# 14      733    3.750000             56
# 15       79    3.729730             74
# 16       75    3.678571             84
# 17      948    3.662500            160
# 18      488    3.622951             61

# %% [markdown]
# Получение информации о книгах, чьи id были получены:

# %%
func_query(
    """
    SELECT *
    FROM
    books
    INNER JOIN (
        SELECT book_id, AVG(rating) AS avg_rating, COUNT(rating) AS ratings_count
        FROM
        ratings
        GROUP BY book_id
        HAVING COUNT(rating) > 50 OR COUNT(rating) = 50)
        AS SQBT ON SQBT.book_id = books.book_id
    ORDER BY avg_rating DESC
    """
)
# Out:
#     book_id  author_id                                              title  \
# 0       302        236  Harry Potter and the Prisoner of Azkaban (Harr...
# 1       722        240  The Fellowship of the Ring (The Lord of the Ri...
# 2       299        236  Harry Potter and the Chamber of Secrets (Harry...
# 3       656        402                                     The Book Thief
# 4       300        236  Harry Potter and the Half-Blood Prince (Harry ...
# 5       399        376                                       Little Women
# 6       301        236  Harry Potter and the Order of the Phoenix (Har...
# 7       750        240                The Hobbit  or There and Back Again
# 8       779        498  The Lightning Thief (Percy Jackson and the Oly...
# 9       405        621                                  Lord of the Flies
# 10      696        106             The Da Vinci Code (Robert Langdon  #2)
# 11      673        235                             The Catcher in the Rye
# 12      627        469                                      The Alchemist
# 13      545        630                                   Romeo and Juliet
# 14      733        372                          The Giver (The Giver  #1)
# 15       79        195                                        Animal Farm
# 16       75        106               Angels & Demons (Robert Langdon  #1)
# 17      948        554                            Twilight (Twilight  #1)
# 18      488        311                                    Of Mice and Men
#
#     num_pages publication_date  publisher_id  book_id  avg_rating  \
# 0         435       2004-05-01           255      302    4.414634
# 1         398       2003-09-05           157      722    4.391892
# 2         341       1999-06-02            24      299    4.287500
# 3         552       2006-03-14             9      656    4.264151
# 4         652       2006-09-16           255      300    4.246575
# 5         449       2004-04-06           267      399    4.192308
# 6         870       2004-09-01           255      301    4.186667
# 7         366       2002-08-15           154      750    4.125000
# 8         375       2006-03-01            91      779    4.080645
# 9         182       1999-10-01           212      405    3.901408
# 10        489       2006-03-28            15      696    3.830508
# 11        277       2001-01-30            31      673    3.825581
# 12        197       1993-05-01           133      627    3.789474
# 13        368       2004-01-01           275      545    3.787879
# 14        208       2006-01-24           101      733    3.750000
# 15        122       2003-05-06           186       79    3.729730
# 16        736       2006-04-01           229       75    3.678571
# 17        501       2006-09-06           176      948    3.662500
# 18        103       2002-01-08           212      488    3.622951
#
#     ratings_count
# 0              82
# 1              74
# 2              80
# 3              53
# 4              73
# 5              52
# 6              75
# 7              88
# 8              62
# 9              71
# 10             59
# 11             86
# 12             57
# 13             66
# 14             56
# 15             74
# 16             84
# 17            160
# 18             61

# %% [markdown]
# Осталось только добавть имена авторов:

# %%
func_query(
    """
    SELECT *
    FROM
    (SELECT *
        FROM
        books
        INNER JOIN (
            SELECT book_id, AVG(rating) AS avg_rating, COUNT(rating) AS ratings_count
            FROM
            ratings
            GROUP BY book_id
            HAVING COUNT(rating) > 50 OR COUNT(rating) = 50)
            AS SQBT ON SQBT.book_id = books.book_id)
            AS D_SQBT
    INNER JOIN authors ON D_SQBT.author_id = authors.author_id
    ORDER BY avg_rating DESC
    """
)
# Out:
#     book_id  author_id                                              title  \
# 0       302        236  Harry Potter and the Prisoner of Azkaban (Harr...
# 1       722        240  The Fellowship of the Ring (The Lord of the Ri...
# 2       299        236  Harry Potter and the Chamber of Secrets (Harry...
# 3       656        402                                     The Book Thief
# 4       300        236  Harry Potter and the Half-Blood Prince (Harry ...
# 5       399        376                                       Little Women
# 6       301        236  Harry Potter and the Order of the Phoenix (Har...
# 7       750        240                The Hobbit  or There and Back Again
# 8       779        498  The Lightning Thief (Percy Jackson and the Oly...
# 9       405        621                                  Lord of the Flies
# 10      696        106             The Da Vinci Code (Robert Langdon  #2)
# 11      673        235                             The Catcher in the Rye
# 12      627        469                                      The Alchemist
# 13      545        630                                   Romeo and Juliet
# 14      733        372                          The Giver (The Giver  #1)
# 15       79        195                                        Animal Farm
# 16       75        106               Angels & Demons (Robert Langdon  #1)
# 17      948        554                            Twilight (Twilight  #1)
# 18      488        311                                    Of Mice and Men
#
#     num_pages publication_date  publisher_id  book_id  avg_rating  \
# 0         435       2004-05-01           255      302    4.414634
# 1         398       2003-09-05           157      722    4.391892
# 2         341       1999-06-02            24      299    4.287500
# 3         552       2006-03-14             9      656    4.264151
# 4         652       2006-09-16           255      300    4.246575
# 5         449       2004-04-06           267      399    4.192308
# 6         870       2004-09-01           255      301    4.186667
# 7         366       2002-08-15           154      750    4.125000
# 8         375       2006-03-01            91      779    4.080645
# 9         182       1999-10-01           212      405    3.901408
# 10        489       2006-03-28            15      696    3.830508
# 11        277       2001-01-30            31      673    3.825581
# 12        197       1993-05-01           133      627    3.789474
# 13        368       2004-01-01           275      545    3.787879
# 14        208       2006-01-24           101      733    3.750000
# 15        122       2003-05-06           186       79    3.729730
# 16        736       2006-04-01           229       75    3.678571
# 17        501       2006-09-06           176      948    3.662500
# 18        103       2002-01-08           212      488    3.622951
#
#     ratings_count  author_id  \
# 0              82        236
# 1              74        240
# 2              80        236
# 3              53        402
# 4              73        236
# 5              52        376
# 6              75        236
# 7              88        240
# 8              62        498
# 9              71        621
# 10             59        106
# 11             86        235
# 12             57        469
# 13             66        630
# 14             56        372
# 15             74        195
# 16             84        106
# 17            160        554
# 18             61        311
#
#                                                author
# 0                          J.K. Rowling/Mary GrandPré
# 1                                      J.R.R. Tolkien
# 2                          J.K. Rowling/Mary GrandPré
# 3                   Markus Zusak/Cao Xuân Việt Khương
# 4                          J.K. Rowling/Mary GrandPré
# 5                                   Louisa May Alcott
# 6                          J.K. Rowling/Mary GrandPré
# 7                                      J.R.R. Tolkien
# 8                                        Rick Riordan
# 9                                     William Golding
# 10                                          Dan Brown
# 11                                      J.D. Salinger
# 12           Paulo Coelho/Alan R. Clarke/Özdemir İnce
# 13  William Shakespeare/Paul Werstine/Barbara A. M...
# 14                                         Lois Lowry
# 15            George Orwell/Boris Grabnar/Peter Škerl
# 16                                          Dan Brown
# 17                                    Stephenie Meyer
# 18                                     John Steinbeck

# %% [markdown]
# Самая высокая средняя оценка за книгу у автора J.K. Rowling/Mary GrandPré.
#
# Если вычислять среднюю оценку для автора, опираясь на полученную таблицу:

# %%
func_query(
    """
    SELECT AVG(avg_rating) AS average_rating, author
    FROM
    (SELECT *
        FROM
        books
        INNER JOIN (
            SELECT book_id, AVG(rating) AS avg_rating, COUNT(rating) AS ratings_count
            FROM
            ratings
            GROUP BY book_id
            HAVING COUNT(rating) > 50 OR COUNT(rating) = 50)
            AS SQBT ON SQBT.book_id = books.book_id
            ) AS D_SQBT
    INNER JOIN authors ON D_SQBT.author_id = authors.author_id
    GROUP BY author
    ORDER BY average_rating DESC
    """
)
# Out:
#     average_rating                                             author
# 0         4.283844                         J.K. Rowling/Mary GrandPré
# 1         4.264151                  Markus Zusak/Cao Xuân Việt Khương
# 2         4.258446                                     J.R.R. Tolkien
# 3         4.192308                                  Louisa May Alcott
# 4         4.080645                                       Rick Riordan
# 5         3.901408                                    William Golding
# 6         3.825581                                      J.D. Salinger
# 7         3.789474           Paulo Coelho/Alan R. Clarke/Özdemir İnce
# 8         3.787879  William Shakespeare/Paul Werstine/Barbara A. M...
# 9         3.754540                                          Dan Brown
# 10        3.750000                                         Lois Lowry
# 11        3.729730            George Orwell/Boris Grabnar/Peter Škerl
# 12        3.662500                                    Stephenie Meyer
# 13        3.622951                                     John Steinbeck

# %% [markdown]
# J.K. Rowling/Mary GrandPré остаётся автором с самой высокой средней оценкой книг (в данном случае осреднённой средней оценкой).
#
# Можно посчитать среднюю оценку всех книг автора (с 50 и более оценок), учитывая каждый отзыв:

# %%
func_query(
    """
    SELECT *
    FROM
    (SELECT *
        FROM
        books
        INNER JOIN (SELECT book_id, rating
        FROM
        ratings
        WHERE book_id IN (SELECT book_id
                        FROM
                        ratings
                        GROUP BY book_id
                        HAVING COUNT(rating) > 50 OR COUNT(rating) = 50)) AS SQBT ON SQBT.book_id = books.book_id
        
    ) AS D_SQBT
    INNER JOIN authors ON D_SQBT.author_id = authors.author_id
   
    """
)
# Out:
#       book_id  author_id                                 title  num_pages  \
# 0          75        106  Angels & Demons (Robert Langdon  #1)        736
# 1          75        106  Angels & Demons (Robert Langdon  #1)        736
# 2          75        106  Angels & Demons (Robert Langdon  #1)        736
# 3          75        106  Angels & Demons (Robert Langdon  #1)        736
# 4          75        106  Angels & Demons (Robert Langdon  #1)        736
# ...       ...        ...                                   ...        ...
# 1408      948        554               Twilight (Twilight  #1)        501
# 1409      948        554               Twilight (Twilight  #1)        501
# 1410      948        554               Twilight (Twilight  #1)        501
# 1411      948        554               Twilight (Twilight  #1)        501
# 1412      948        554               Twilight (Twilight  #1)        501
#
#      publication_date  publisher_id  book_id  rating  author_id  \
# 0          2006-04-01           229       75       5        106
# 1          2006-04-01           229       75       4        106
# 2          2006-04-01           229       75       4        106
# 3          2006-04-01           229       75       4        106
# 4          2006-04-01           229       75       4        106
# ...               ...           ...      ...     ...        ...
# 1408       2006-09-06           176      948       3        554
# 1409       2006-09-06           176      948       3        554
# 1410       2006-09-06           176      948       5        554
# 1411       2006-09-06           176      948       4        554
# 1412       2006-09-06           176      948       5        554
#
#                author
# 0           Dan Brown
# 1           Dan Brown
# 2           Dan Brown
# 3           Dan Brown
# 4           Dan Brown
# ...               ...
# 1408  Stephenie Meyer
# 1409  Stephenie Meyer
# 1410  Stephenie Meyer
# 1411  Stephenie Meyer
# 1412  Stephenie Meyer
#
# [1413 rows x 10 columns]

# %%
func_query(
    """
    SELECT AVG(rating) AS average_rating, author
    FROM
    (SELECT *
        FROM
        books
        INNER JOIN (SELECT book_id, rating
        FROM
        ratings
        WHERE book_id IN (SELECT book_id
                        FROM
                        ratings
                        GROUP BY book_id
                        HAVING COUNT(rating) > 50 OR COUNT(rating) = 50)) AS SQBT ON SQBT.book_id = books.book_id
        
    ) AS D_SQBT
    INNER JOIN authors ON D_SQBT.author_id = authors.author_id
   GROUP BY author
   ORDER BY average_rating DESC
    """
)
# Out:
#     average_rating                                             author
# 0         4.287097                         J.K. Rowling/Mary GrandPré
# 1         4.264151                  Markus Zusak/Cao Xuân Việt Khương
# 2         4.246914                                     J.R.R. Tolkien
# 3         4.192308                                  Louisa May Alcott
# 4         4.080645                                       Rick Riordan
# 5         3.901408                                    William Golding
# 6         3.825581                                      J.D. Salinger
# 7         3.789474           Paulo Coelho/Alan R. Clarke/Özdemir İnce
# 8         3.787879  William Shakespeare/Paul Werstine/Barbara A. M...
# 9         3.750000                                         Lois Lowry
# 10        3.741259                                          Dan Brown
# 11        3.729730            George Orwell/Boris Grabnar/Peter Škerl
# 12        3.662500                                    Stephenie Meyer
# 13        3.622951                                     John Steinbeck

# %% [markdown]
# Автор с самой высокой средней оценкой книг - J.K. Rowling/Mary GrandPré. Средняя оценка 4,287 (средняя средних - 4,284).

# %% [markdown]
# # 5. Определение среднего количества обзоров от пользователей, которые поставили больше 50 оценок

# %% [markdown]
# Сначала нужно определить `username` полльзователй, которые поставили больше 50 оценок:

# %%
func_query(
    """
    SELECT username, COUNT('rating_id') AS ratings_count
    FROM
    ratings
    GROUP BY username
    HAVING COUNT('rating_id') > 50
    """
)
# Out:
#          username  ratings_count
# 0     sfitzgerald             55
# 1  jennifermiller             53
# 2          xdavis             51
# 3          paul88             56
# 4      martinadam             56
# 5       richard89             55

# %% [markdown]
# Из таблицы с обзорами отбираются только те, что сделали пользователи из полученного списка:

# %%
func_query(
    """
    SELECT *
    FROM
    reviews
    WHERE username IN (SELECT username
                        FROM
                        ratings
                        GROUP BY username
                        HAVING COUNT('rating_id') > 50)
    """
)
# Out:
#      review_id  book_id        username  \
# 0           16        6     sfitzgerald
# 1           20        8       richard89
# 2           30       11       richard89
# 3           40       15      martinadam
# 4           51       18  jennifermiller
# ..         ...      ...             ...
# 141       2743      982          paul88
# 142       2750      985  jennifermiller
# 143       2773      994     sfitzgerald
# 144       2782      997       richard89
# 145       2789      999      martinadam
#
#                                                   text
# 0    Miss effort gun strong surface civil. Resource...
# 1    Sister statement than reflect. Crime hot guess...
# 2    Far visit rich describe. Heart blue generation...
# 3    Deal fund decision management million black me...
# 4    Lose act beautiful. Drive responsibility every...
# ..                                                 ...
# 141  Station during food foot every end hour. Job o...
# 142  Prove instead wrong town. Police everybody hav...
# 143  Concern lawyer a quality fish reason not. Agen...
# 144  Step show wait answer range adult. Cell oil al...
# 145  Later hospital turn easy community. Fact same ...
#
# [146 rows x 4 columns]

# %% [markdown]
# Количество обзоров, сделанных каждым пользователем из списка:

# %%
func_query(
    """
    SELECT username, COUNT(review_id) AS reviews_count
    FROM
    reviews
    WHERE username IN (SELECT username
                        FROM
                        ratings
                        GROUP BY username
                        HAVING COUNT('rating_id') > 50)
    GROUP BY username
    """
)
# Out:
#          username  reviews_count
# 0     sfitzgerald             28
# 1  jennifermiller             25
# 2          xdavis             18
# 3          paul88             22
# 4      martinadam             27
# 5       richard89             26

# %% [markdown]
# Среднее количество обзоров от пользователей, которые поставили больше 50 оценок:

# %%
func_query(
    """
    SELECT AVG(reviews_count) AS avg_count
    FROM
        (SELECT username, COUNT(review_id) AS reviews_count
        FROM
        reviews
        WHERE username IN (SELECT username
                        FROM
                        ratings
                        GROUP BY username
                        HAVING COUNT('rating_id') > 50)
        GROUP BY username) AS SQBT
    """
)
# Out:
#    avg_count
# 0  24.333333
